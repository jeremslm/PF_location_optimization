# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
K_REFINED = 0 # None = all refinements; set e.g. 1 to truncate Bayesian after k-th refinement

# %%
LBFGS_SWEEP = 'convergence_w5_l_temp'
BAYESIAN_SWEEP = 'convergence_w5_b_temp'

# %%
BASE = '../examples/comparisons/combined_boundary_DIIID'

# %%
def load_run(run_dir):
    for fname in ('results.json', 'checkpoint.json'):
        path = os.path.join(run_dir, fname)
        if not os.path.exists(path):
            continue
        with open(path) as f:
            raw = json.load(f)
        methods = raw.get('methods', {})
        if not methods:
            return None
        method_name, inner = next(iter(methods.items()))
        d = dict(inner)
        d['method'] = method_name
        d['optimization_settings'] = raw.get('optimization_settings', {})
        d['source'] = fname
        d['elapsed'] = inner.get('time', float('nan'))
        return d
    return None

# %%
def discover_runs(base):
    runs = []
    for sweep in [LBFGS_SWEEP, BAYESIAN_SWEEP]:
        sweep_dir = os.path.join(base, sweep)
        if not os.path.isdir(sweep_dir):
            print(f"not found: {sweep_dir}")
            continue
        for config in sorted(os.listdir(sweep_dir)):
            config_dir = os.path.join(sweep_dir, config)
            if not os.path.isdir(config_dir):
                continue
            for run in sorted(os.listdir(config_dir)):
                run_dir = os.path.join(config_dir, run)
                if not os.path.isdir(run_dir):
                    continue
                d = load_run(run_dir)
                if d is None:
                    continue
                s = d.get('optimization_settings', {})
                runs.append({
                    'sweep': sweep,
                    'config': config,
                    'run': run,
                    'run_dir': run_dir,
                    'source': d['source'],
                    'method': d.get('method', '?'),
                    'weight_fb': s.get('weight_fb', float('nan')),
                    'alpha': s.get('alpha', float('nan')),
                    'num_coils': s.get('num_coils', '?'),
                    'n_evals': d.get('n_evals', float('nan')),
                    'best_cost': d.get('best_cost', float('nan')),
                    'best_flux_err': d.get('best_flux_err', float('nan')),
                    'best_fb_cost': d.get('best_fb_cost', float('nan')),
                    'fb_failures': d.get('fb_failures', float('nan')),
                    'elapsed': d.get('elapsed', d.get('time', float('nan'))),
                    'stopping': d.get('stopping', '?'),
                    'data': d,
                })
    return runs

runs = discover_runs(BASE)
print(f"{len(runs)} runs found")
for r in runs:
    print(f"  {r['sweep']}/{r['config']}/{r['run']}  method={r['method']}  weight_fb={r['weight_fb']:.0e}  best={r['best_cost']:.4e}  evals={r['n_evals']}  stop={r['stopping']}")
# Out:
# 32 runs found
#   convergence_w5_l_temp/alpha:1.0,weight:1e-01,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=8.8317e-02  evals=935  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-01,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=5.3967e-03  evals=1050  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-01,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=1.2234e-09  evals=738  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-01,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=1.3180e-02  evals=1700  stop=exceeded wall time
#   convergence_w5_l_temp/alpha:1.0,weight:1e-02,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.0000e+00  evals=645  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-02,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=2.5983e-03  evals=1071  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-02,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.1243e-09  evals=783  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-02,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.0379e-02  evals=1144  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-03,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=2.2078e-01  evals=765  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-03,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=2.2135e-03  evals=1278  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-03,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=1.1441e-09  evals=900  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-03,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=2.8988e-02  evals=1432  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-04,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=6.0102e-02  evals=1490  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-04,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=2.1458e-03  evals=1166  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-04,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=1.1444e-09  evals=810  stop=converged
#   convergence_w5_l_temp/alpha:1.0,weight:1e-04,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=8.7538e-03  evals=1674  stop=exceeded wall time
#   convergence_w5_b_temp/alpha:1,weight:1e-01,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-01  best=3.1975e-02  evals=623  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-01,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-01  best=2.2548e-02  evals=501  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-01,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-01  best=1.0000e+00  evals=864  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-01,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-01  best=6.5618e-03  evals=784  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-02,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-02  best=2.7591e-02  evals=451  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-02,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-02  best=8.1131e-03  evals=524  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-02,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-02  best=8.3557e-02  evals=693  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-02,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-02  best=1.7635e-02  evals=635  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-03,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-03  best=2.7201e-02  evals=462  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-03,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-03  best=2.3754e-02  evals=465  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-03,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-03  best=8.0161e-01  evals=286  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-03,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-03  best=2.2114e-03  evals=723  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-04,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-04  best=3.5151e-02  evals=463  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-04,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-04  best=2.1841e-02  evals=424  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-04,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-04  best=1.0000e+00  evals=387  stop=all refinements completed
#   convergence_w5_b_temp/alpha:1,weight:1e-04,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-04  best=1.9722e-03  evals=745  stop=all refinements completed

# %%
rows = []
for r in runs:
    d = r['data']
    if 'cost_history' not in d:
        continue
    alpha = d.get('optimization_settings', {}).get('alpha', 0.75)
    total = np.array(d['cost_history'], dtype=float)
    flux_h = np.array([x if x is not None else np.nan for x in d.get('flux_err_history', [])], dtype=float)
    fb_h = np.array([x if x is not None else np.nan for x in d.get('fb_cost_history', [])], dtype=float)

    truncated = False
    if r['method'] == 'Bayesian' and K_REFINED is not None:
        n_bay = d.get('n_bayesian_evals', len(total))
        ref_evals = d.get('refinement_evals', [])
        trunc = n_bay + sum(ref_evals[:min(K_REFINED, len(ref_evals))])
        if trunc > 0:
            total = total[:trunc]
            flux_h = flux_h[:trunc]
            fb_h = fb_h[:trunc]
            truncated = True
        t_bay = d.get('time_bayesian_phase', float('nan'))
        ref_times = d.get('refinement_times', [])
        elapsed_h = (t_bay + sum(ref_times[:min(K_REFINED, len(ref_times))])) / 3600
    else:
        elapsed_h = r['elapsed'] / 3600

    if len(total) == 0:
        continue

    if truncated:
        idx = int(np.nanargmin(total))
        best_flux = float(flux_h[idx]) if idx < len(flux_h) and np.isfinite(flux_h[idx]) else float(np.nanmin(flux_h))
        best_fb = float(fb_h[idx]) if idx < len(fb_h) and np.isfinite(fb_h[idx]) else float(np.nanmin(fb_h))
    else:
        best_flux = float(d.get('best_flux_err', float('nan')))
        best_fb = float(d.get('best_fb_cost', float('nan')))

    rows.append({
        'sweep': r['sweep'],
        'method': r['method'],
        'weight_fb': r['weight_fb'],
        'num_coils': r['num_coils'],
        'alpha': alpha,
        'best_cost_stored': float(np.nanmin(total)),
        'best_flux_err': best_flux,
        'best_fb_cost': best_fb,
        'init_fixed': float(d.get('initial_fixed_cost', float('nan'))),
        'init_fb': float(d.get('initial_fb_cost', float('nan'))),
        'fb_failures': r['fb_failures'],
        'n_evals': len(total),
        'elapsed_h': elapsed_h,
        'stopping': r['stopping'],
    })

df = pd.DataFrame(rows)

# per weight_fb pair: norm = max(init_lbfgs, init_bayesian)
norm_df = df.groupby('weight_fb')[['init_fixed', 'init_fb']].max()
norm_df.columns = ['norm_fixed', 'norm_fb']
df = df.join(norm_df, on='weight_fb')

df['best_cost_shared'] = (
    (1 - df['alpha']) * df['best_flux_err'] / df['norm_fixed'] +
    df['alpha'] * df['best_fb_cost'] / df['norm_fb']
)

df = df.sort_values(['weight_fb', 'method'])
pd.set_option('display.float_format', '{:.4e}'.format)
df
# Out:
#                     sweep              method  weight_fb  num_coils  \
# 28  convergence_w5_b_temp            Bayesian 1.0000e-04          2
# 29  convergence_w5_b_temp            Bayesian 1.0000e-04          3
# 30  convergence_w5_b_temp            Bayesian 1.0000e-04          4
# 31  convergence_w5_b_temp            Bayesian 1.0000e-04          5
# 12  convergence_w5_l_temp  Multi-start L-BFGS 1.0000e-04
# 3  6.2110e-02          165     1700 2.4004e+01         exceeded wall time
#
#     norm_fixed    norm_fb  best_cost_shared
# 28  1.7483e-01 1.0000e+06        7.1162e-10
# 29  1.7483e-01 1.0000e+06        2.2812e-10
# 30  1.7483e-01 1.0000e+06        2.2451e-10
# 31  1.7483e-01 1.0000e+06        2.5773e-11
# 12  1.7483e-01 1.0000e+06        1.6149e-09
# 13  1.7483e-01 1.0000e+06        8.7140e-11
# 14  1.7483e-01 1.0000e+06        1.1444e-09
# 15  1.7483e-01 1.0000e+06        4.5742e-10
# 24  1.7483e-01 1.0000e+06        5.5069e-10
# 25  1.7483e-01 1.0000e+06        2.4815e-10
# 26  1.7483e-01 1.0000e+06        1.7990e-10
# 27  1.7483e-01 1.0000e+06        2.6851e-11
# 8   1.7483e-01 1.0000e+06        6.4252e-09
# 9   1.7483e-01 1.0000e+06        8.7397e-11
# 10  1.7483e-01 1.0000e+06        1.1441e-09
# 11  1.7483e-01 1.0000e+06        1.1232e-09
# 20  1.7483e-01 1.0000e+06        5.5867e-10
# 21  1.7483e-01 1.0000e+06        8.6506e-11
# 22  1.7483e-01 1.0000e+06        2.1667e-10
# 23  1.7483e-01 1.0000e+06        1.1899e-10
# 4   1.7483e-01 1.0000e+06        2.8895e-08
# 5   1.7483e-01 1.0000e+06        8.6213e-11
# 6   1.7483e-01 1.0000e+06        1.1243e-09
# 7   1.7483e-01 1.0000e+06        5.2838e-10
# 16  1.7483e-01 1.0000e+06        7.2501e-10
# 17  1.7483e-01 1.0000e+06        3.1894e-10
# 18  1.7483e-01 1.0000e+06        9.8576e-11
# 19  1.7483e-01 1.0000e+06        3.9389e-11
# 0   1.7483e-01 1.0000e+06        2.1409e-09
# 1   1.7483e-01 1.0000e+06        2.2622e-10
# 2   1.7483e-01 1.0000e+06        1.2234e-09
# 3   1.7483e-01 1.0000e+06        8.1861e-10

# %%
# fix norm: per (weight_fb, num_coils), drop 1e6 init_fb sentinel
df = df.drop(columns=['norm_fixed', 'norm_fb', 'best_cost_shared'])
clean = df.assign(
    init_fixed=df['init_fixed'].where(df['init_fixed'] < 1e5),
    init_fb=df['init_fb'].where(df['init_fb'] < 1e5),
)
norm_df = clean.groupby(['weight_fb', 'num_coils'])[['init_fixed', 'init_fb']].max()
norm_df.columns = ['norm_fixed', 'norm_fb']
df = df.join(norm_df, on=['weight_fb', 'num_coils'])
df['best_cost_shared'] = (
    (1 - df['alpha']) * df['best_flux_err'] / df['norm_fixed'] +
    df['alpha'] * df['best_fb_cost'] / df['norm_fb']
)
df[['sweep', 'method', 'weight_fb', 'num_coils', 'init_fixed', 'init_fb', 'norm_fixed', 'norm_fb', 'best_cost_shared']]
# Out:
#                     sweep              method  weight_fb  num_coils  \
# 28  convergence_w5_b_temp            Bayesian 1.0000e-04          2
# 29  convergence_w5_b_temp            Bayesian 1.0000e-04          3
# 30  convergence_w5_b_temp            Bayesian 1.0000e-04          4
# 31  convergence_w5_b_temp            Bayesian 1.0000e-04          5
# 12  convergence_w5_l_temp  Multi-start L-BFGS 1.0000e-04
# 5   1.7483e-01 3.3181e-02  1.7483e-01 3.3181e-02        2.5983e-03
# 6   4.0241e-02 1.0000e+06  4.0241e-02 2.1667e-04        5.1891e+00
# 7   1.6873e-01 5.0910e-02  1.6873e-01 5.0910e-02        1.0379e-02
# 16  4.3785e-02 2.2674e-02  1.1529e-01 2.4241e-02        2.9908e-02
# 17  2.0025e-02 1.4145e-02  1.7483e-01 4.1919e-02        7.6084e-03
# 18  1.5327e-03 9.8576e-05  4.0241e-02 9.8576e-05        1.0000e+00
# 19  3.1209e-02 6.0027e-03  1.6873e-01 6.2110e-02        6.3418e-04
# 0   1.1529e-01 2.4241e-02  1.1529e-01 2.4241e-02        8.8317e-02
# 1   1.7483e-01 4.1919e-02  1.7483e-01 4.1919e-02        5.3967e-03
# 2   4.0241e-02 1.0000e+06  4.0241e-02 9.8576e-05        1.2411e+01
# 3   1.6873e-01 6.2110e-02  1.6873e-01 6.2110e-02        1.3180e-02

# %%
# run counts split by method
for method in sorted(df['method'].unique()):
    sub = df[df['method'] == method]
    piv = sub.groupby(['num_coils', 'weight_fb']).size().unstack(fill_value=0).astype(int)
    piv = piv.reindex(sorted(piv.columns), axis=1)
    piv.columns = [f'{c:.0e}' for c in piv.columns]
    print(method)
    display(piv)
# Out:
# Bayesian
#            1e-04  1e-03  1e-02  1e-01
# num_coils
# 2              1      1      1      1
# 3              1      1      1      1
# 4              1      1      1      1
# 5              1      1      1      1
# Multi-start L-BFGS
#            1e-04  1e-03  1e-02  1e-01
# num_coils
# 2              1      1      1      1
# 3              1      1      1      1
# 4              1      1      1      1
# 5              1      1      1      1

# %%
# raw fb cost split by method (rows num_coils, cols weight_fb)
for method in sorted(df['method'].unique()):
    sub = df[df['method'] == method]
    piv = sub.groupby(['num_coils', 'weight_fb'])['best_fb_cost'].min().unstack()
    piv = piv.reindex(sorted(piv.columns), axis=1)
    piv.columns = [f'{c:.0e}' for c in piv.columns]
    print(method)
    display(piv)

with open('target=free_diiid_3_coil/fb_candidate_cost_results.json') as _f:
    _true_raw = json.load(_f)
WEIGHTS_STR = ['1e-04', '1e-03', '1e-02', '1e-01']
true_piv = pd.DataFrame([{w: _true_raw.get(w, float('nan')) for w in WEIGHTS_STR}], index=['True DIII-D'])
print('True DIII-D (3 coils)')
display(true_piv.style.format('{:.4e}'))
# Out:
# Bayesian
#                1e-04      1e-03      1e-02      1e-01
# num_coils
# 2         7.1162e-04 5.5069e-04 5.5867e-04 7.2501e-04
# 3         2.2812e-04 2.4815e-04 8.6506e-05 3.1894e-04
# 4         2.2451e-04 1.7990e-04 2.1667e-04 9.8576e-05
# 5         2.5773e-05 2.6851e-05 1.1899e-04 3.9389e-05
# Multi-start L-BFGS
#                1e-04      1e-03      1e-02      1e-01
# num_coils
# 2         1.6149e-03 6.4252e-03 2.8895e-02 2.1409e-03
# 3         8.7140e-05 8.7397e-05 8.6213e-05 2.2622e-04
# 4         1.1444e-03 1.1441e-03 1.1243e-03 1.2234e-03
# 5         4.5742e-04 1.1232e-03 5.2838e-04 8.1861e-04
# True DIII-D (3 coils)
# <style type="text/css">
# </style>
# <table id="T_9f301">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f301_level0_col0" class="col_heading level0 col0" >1e-04</th>
#       <th id="T_9f301_level0_col1" class="col_heading level0 col1" >1e-03</th>
#       <th id="T_9f301_level0_col2" class="col_heading level0 col2" >1e-02</th>
#       <th id="T_9f301_level0_col3" class="col_heading level0 col3" >1e-01</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f301_level0_row0" class="row_heading level0 row0" >True DIII-D</th>
#       <td id="T_9f301_row0_col0" class="data row0 col0" >7.8437e-12</td>
#       <td id="T_9f301_row0_col1" class="data row0 col1" >7.8437e-12</td>
#       <td id="T_9f301_row0_col2" class="data row0 col2" >7.8437e-12</td>
#       <td id="T_9f301_row0_col3" class="data row0 col3" >7.8437e-12</td>
#     </tr>
#   </tbody>
# </table>

# %%
true_vals = {w: _true_raw.get(w, float('nan')) for w in WEIGHTS_STR}

methods = sorted(df['method'].unique())
fig, axes = plt.subplots(1, len(methods), figsize=(7 * len(methods), 5))
if len(methods) == 1:
    axes = [axes]

for ax, method in zip(axes, methods):
    ratio_rows = {}
    for nc in sorted(df['num_coils'].unique()):
        row = {}
        for w_str in WEIGHTS_STR:
            w_float = float(w_str)
            match = df[(df['method'] == method) & (df['num_coils'] == nc) & np.isclose(df['weight_fb'], w_float)]
            opt_best = float(match['best_fb_cost'].min()) if len(match) > 0 else float('nan')
            row[w_str] = opt_best / true_vals[w_str]
        ratio_rows[nc] = row
    ratio_df = pd.DataFrame(ratio_rows).T[WEIGHTS_STR]
    ratio_df.index.name = 'num_coils'
    sns.heatmap(ratio_df, annot=True, fmt='.3f', cmap='RdYlGn_r', ax=ax, center=1.0,
                cbar_kws={'label': 'optimizer fb / true fb'})
    ax.set_title(f'{method}\nfb_cost ratio vs True DIII-D — <1 optimizer better')
    ax.set_xlabel('weight_fb')
    ax.set_ylabel('num_coils')

plt.tight_layout()
plt.show()

# %%
with open('target=free_diiid_3_coil/fb_candidate_cost_results.json') as f:
    _true = json.load(f)

WEIGHTS_STR = ['1e-04', '1e-03', '1e-02', '1e-01']
true_row = [_true.get(w, float('nan')) for w in WEIGHTS_STR]
sub3 = df[df['num_coils'] == 3]

for method_label, method_key in [('Bayesian', 'Bayesian'), ('L-BFGS', 'Multi-start L-BFGS')]:
    opt_row = []
    for w_str in WEIGHTS_STR:
        w_float = float(w_str)
        match = sub3[(sub3['method'] == method_key) & np.isclose(sub3['weight_fb'], w_float)]
        opt_row.append(float(match['best_fb_cost'].min()) if len(match) > 0 else float('nan'))
    tbl = pd.DataFrame(
        [true_row, opt_row],
        index=['True DIII-D (3 coils)', method_label],
        columns=WEIGHTS_STR
    )
    print(f'True DIII-D vs {method_label} | raw fb_cost | 3 coils')
    display(tbl.style.format('{:.4e}'))
    print()
# Out:
# True DIII-D vs Bayesian | raw fb_cost | 3 coils
# <style type="text/css">
# </style>
# <table id="T_e700e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e700e_level0_col0" class="col_heading level0 col0" >1e-04</th>
#       <th id="T_e700e_level0_col1" class="col_heading level0 col1" >1e-03</th>
#       <th id="T_e700e_level0_col2" class="col_heading level0 col2" >1e-02</th>
#       <th id="T_e700e_level0_col3" class="col_heading level0 col3" >1e-01</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e700e_level0_row0" class="row_heading level0 row0" >True DIII-D (3 coils)</th>
#       <td id="T_e700e_row0_col0" class="data row0 col0" >7.8437e-12</td>
#       <td id="T_e700e_row0_col1" class="data row0 col1" >7.8437e-12</td>
#       <td id="T_e700e_row0_col2" class="data row0 col2" >7.8437e-12</td>
#       <td id="T_e700e_row0_col3" class="data row0 col3" >7.8437e-12</td>
#     </tr>
#     <tr>
#       <th id="T_e700e_level0_row1" class="row_heading level0 row1" >Bayesian</th>
#       <td id="T_e700e_row1_col0" class="data row1 col0" >2.2812e-04</td>
#       <td id="T_e700e_row1_col1" class="data row1 col1" >2.4815e-04</td>
#       <td id="T_e700e_row1_col2" class="data row1 col2" >8.6506e-05</td>
#       <td id="T_e700e_row1_col3" class="data row1 col3" >3.1894e-04</td>
#     </tr>
#   </tbody>
# </table>
# True DIII-D vs L-BFGS | raw fb_cost | 3 coils
# <style type="text/css">
# </style>
# <table id="T_56575">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56575_level0_col0" class="col_heading level0 col0" >1e-04</th>
#       <th id="T_56575_level0_col1" class="col_heading level0 col1" >1e-03</th>
#       <th id="T_56575_level0_col2" class="col_heading level0 col2" >1e-02</th>
#       <th id="T_56575_level0_col3" class="col_heading level0 col3" >1e-01</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56575_level0_row0" class="row_heading level0 row0" >True DIII-D (3 coils)</th>
#       <td id="T_56575_row0_col0" class="data row0 col0" >7.8437e-12</td>
#       <td id="T_56575_row0_col1" class="data row0 col1" >7.8437e-12</td>
#       <td id="T_56575_row0_col2" class="data row0 col2" >7.8437e-12</td>
#       <td id="T_56575_row0_col3" class="data row0 col3" >7.8437e-12</td>
#     </tr>
#     <tr>
#       <th id="T_56575_level0_row1" class="row_heading level0 row1" >L-BFGS</th>
#       <td id="T_56575_row1_col0" class="data row1 col0" >8.7140e-05</td>
#       <td id="T_56575_row1_col1" class="data row1 col1" >8.7397e-05</td>
#       <td id="T_56575_row1_col2" class="data row1 col2" >8.6213e-05</td>
#       <td id="T_56575_row1_col3" class="data row1 col3" >2.2622e-04</td>
#     </tr>
#   </tbody>
# </table>

# %%
# bay vs lbfgs heatmaps across (coils x weight_fb) - mirrors bay_vs_lbfgs.ipynb style
# Gap measured on free-boundary cost (best_fb_cost) only.
best = df.sort_values('best_fb_cost').groupby(['num_coils', 'weight_fb', 'method'], sort=False).first().reset_index()

bay = best[best['method'] == 'Bayesian'].set_index(['num_coils', 'weight_fb'])
lbf = best[best['method'] != 'Bayesian'].set_index(['num_coils', 'weight_fb'])

cmp = pd.DataFrame(index=bay.index.union(lbf.index))
cmp['bayes_fb'] = bay['best_fb_cost']
cmp['lbfgs_fb'] = lbf['best_fb_cost']
cmp['bayes_evals'] = bay['n_evals']
cmp['lbfgs_evals'] = lbf['n_evals']
cmp['bayes_time_h'] = bay['elapsed_h']
cmp['lbfgs_time_h'] = lbf['elapsed_h']
cmp['fb_gap_lbfgs'] = (cmp['bayes_fb'] - cmp['lbfgs_fb']) / cmp['lbfgs_fb'] * 100
cmp['eval_ratio'] = cmp['lbfgs_evals'] / cmp['bayes_evals']
cmp = cmp.reset_index()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, col, title, fmt in [
    (axes[0], 'eval_ratio', 'Eval ratio: L-BFGS / Bayesian', '.2f'),
    (axes[1], 'fb_gap_lbfgs', 'fb cost gap vs L-BFGS (%) - positive = BO worse', '.1f'),
]:
    pivot = cmp.pivot_table(index='num_coils', columns='weight_fb', values=col)
    pivot = pivot.reindex(sorted(pivot.columns), axis=1)
    pivot.columns = [f'{c:.0e}' for c in pivot.columns]
    cmap = 'YlGn' if col == 'eval_ratio' else 'RdYlGn_r'
    center = None if col == 'eval_ratio' else 0
    sns.heatmap(pivot, annot=True, fmt=fmt, cmap=cmap, ax=ax, center=center)
    ax.set_title(title)
    ax.set_xlabel('weight_fb')
    ax.set_ylabel('coils')
plt.tight_layout()
plt.show()

# timing heatmaps
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
for ax, mcol, title in [
    (axes[0], 'bayes_time_h', 'Bayesian wall time (h)'),
    (axes[1], 'lbfgs_time_h', 'L-BFGS wall time (h)'),
]:
    pivot = cmp.pivot_table(index='num_coils', columns='weight_fb', values=mcol)
    pivot = pivot.reindex(sorted(pivot.columns), axis=1)
    pivot.columns = [f'{c:.0e}' for c in pivot.columns]
    sns.heatmap(pivot, annot=True, fmt='.2f', cmap='YlOrRd', ax=ax)
    ax.set_title(title)
    ax.set_xlabel('weight_fb')
    ax.set_ylabel('coils')
plt.tight_layout()
plt.show()

# %%
# bayesian refinement improvement: % cost reduction from end of GP phase to end of each refinement
ref_rows = []
for r in runs:
    if r['method'] != 'Bayesian':
        continue
    d = r['data']
    total = np.array(d['cost_history'], dtype=float)
    n_bay = d.get('n_bayesian_evals', 0)
    ref_evals = d.get('refinement_evals', []) or []
    if n_bay == 0 or len(total) <= n_bay:
        continue
    best_gp = float(np.nanmin(total[:n_bay]))
    cum = n_bay
    cum_best = best_gp
    for i, re in enumerate(ref_evals):
        prev_best = cum_best
        cum += re
        cum_best = float(np.nanmin(total[:cum]))
        step_improve = (prev_best - cum_best) / prev_best * 100 if prev_best > 0 else float('nan')
        cumulative_improve = (best_gp - cum_best) / best_gp * 100 if best_gp > 0 else float('nan')
        ref_rows.append({
            'num_coils': r['num_coils'],
            'weight_fb': r['weight_fb'],
            'refinement': i + 1,
            'best_gp': best_gp,
            'best_after_ref': cum_best,
            'step_improve_pct': step_improve,
            'cumulative_improve_pct': cumulative_improve,
            'n_evals_in_ref': re,
        })

ref_df = pd.DataFrame(ref_rows)
print('per-refinement breakdown:')
display(ref_df)

# total improvement per (coils, weight_fb): last refinement
total_imp = ref_df.sort_values('refinement').groupby(['num_coils', 'weight_fb']).last().reset_index()

fig, axes = plt.subplots(1, 1, figsize=(7, 5))
piv_total = total_imp.pivot_table(index='num_coils', columns='weight_fb', values='cumulative_improve_pct')
piv_total = piv_total.reindex(sorted(piv_total.columns), axis=1)
piv_total.columns = [f'{c:.0e}' for c in piv_total.columns]
sns.heatmap(piv_total, annot=True, fmt='.1f', cmap='YlGn', ax=axes)
axes.set_title('Bayesian: total % cost improvement from refinements (GP_end -> final)')
axes.set_xlabel('weight_fb')
axes.set_ylabel('coils')

plt.tight_layout()
plt.show()
# Out:
# per-refinement breakdown:
#     num_coils  weight_fb  refinement    best_gp  best_after_ref  \
# 0           2 1.0000e-01           1 3.1975e-02      3.1975e-02
# 1           2 1.0000e-01           2 3.1975e-02      3.1975e-02
# 2           2 1.0000e-01           3 3.1975e-02      3.1975e-02
# 3           3 1.0000e-01           1 2.2548e-02      2.2548e-02
# 4           3 1.0000e-01           2 2.2548e-02      2.2548e-02
# 5           3 1.0000e-01           3 2.2548e-02      2.2548e-02
# 6           4 1.0000e-01           1 1.0000e+00      1.0000e+00
# 7           4 1.0000e-01           2 1.0000e+00      1.0000e+00
# 8           4 1.0000e-01           3 1.0000e+00      1.0000e+00
# 9           5 1.0000e-01           1 6.5618e-03      6.5618e-03
# 10          5 1.0000e-01           2 6.5618e-03      6.5618e-03
# 11          5 1.0000e-01           3 6.5618e-03      6.5618e-03
# 12          2 1.0000e-02           1 2.7591e-02      2.7591e-02
# 13          2 1.0000e-02           2 2.7591e-02      2.7591e-02
# 14          2 1.0000e-02           3 2.7591e-02      2.7591e-02
# 15          3 1.0000e-02           1 8.1131e-03      8.1131e-03
# 16          3 1.0000e-02           2 8.1131e-03      8.1131e-03
# 17          3 1.0000e-02           3 8.1131e-03      8.1131e-03
# 18          4 1.0000e-02           1 1.0000e+00      1.8470e-01
# 19          4 1.0000e-02           2 1.0000e+00      1.8470e-01
# 20          4 1.0000e-02           3 1.0000e+00      8.3557e-02
# 21          5 1.0000e-02           1 1.7635e-02      1.7635e-02
# 22          5 1.0000e-02           2 1.7635e-02      1.7635e-02
# 23          5 1.0000e-02           3 1.7635e-02      1.7635e-02
# 24          2 1.0000e-03           1 2.7201e-02      2.7201e-02
# 25          2 1.0000e-03           2 2.7201e-02      2.7201e-02
# 26          2 1.0000e-03           3 2.7201e-02      2.7201e-02
# 27          3 1.0000e-03           1 2.3754e-02      2.3754e-02
# 28          3 1.0000e-03           2 2.3754e-02      2.3754e-02
# 29          3 1.0000e-03           3 2.3754e-02      2.3754e-02
# 30          4 1.0000e-03           1 8.0161e-01      8.0161e-01
# 31          4 1.0000e-03           2 8.0161e-01      8.0161e-01
# 32          4 1.0000e-03           3 8.0161e-01      8.0161e-01
# 33          5 1.0000e-03           1 2.2114e-03      2.2114e-03
# 34          5 1.0000e-03           2 2.2114e-03      2.2114e-03
# 35          5 1.0000e-03           3 2.2114e-03      2.2114e-03
# 36          2 1.0000e-04           1 3.5151e-02      3.5151e-02
# 37          2 1.0000e-04           2 3.5151e-02      3.5151e-02
# 38          2 1.0000e-04           3 3.5151e-02      3.5151e-02
# 39          3 1.0000e-04           1 2.1841e-02      2.1841e-02
# 40          3 1.0000e-04           2 2.1841e-02      2.1841e-02
# 41          3 1.0000e-04           3 2.1841e-02      2.1841e-02
# 42          4 1.0000e-04           1 1.0000e+00      1.0000e+00
# 43          4 1.0000e-04           2 1.0000e+00      1.0000e+00
# 44          4 1.0000e-04           3 1.0000e+00      1.0000e+00
# 45          5 1.0000e-04           1 1.9722e-03      1.9722e-03
# 46          5 1.0000e-04           2 1.9722e-03      1.9722e-03
# 47          5 1.0000e-04           3 1.9722e-03      1.9722e-03
#
#     step_improve_pct  cumulative_improve_pct  n_evals_in_ref
# 0         0.0000e+00              0.0000e+00             190
# 1         0.0000e+00              0.0000e+00             210
# 2         0.0000e+00              0.0000e+00             105
# 3         0.0000e+00              0.0000e+00             133
# 4         0.0000e+00              0.0000e+00             126
# 5         0.0000e+00              0.0000e+00             126
# 6         0.0000e+00              0.0000e+00             144
# 7         0.0000e+00              0.0000e+00             180
# 8         0.0000e+00              0.0000e+00             414
# 9         0.0000e+00              0.0000e+00             220
# 10        0.0000e+00              0.0000e+00             165
# 11        0.0000e+00              0.0000e+00             231
# 12        0.0000e+00              0.0000e+00              80
# 13        0.0000e+00              0.0000e+00              65
# 14        0.0000e+00              0.0000e+00             175
# 15        0.0000e+00              0.0000e+00             140
# 16        0.0000e+00              0.0000e+00             147
# 17        0.0000e+00              0.0000e+00             119
# 18        8.1530e+01              8.1530e+01             189
# 19        0.0000e+00              8.1530e+01             189
# 20        5.4760e+01              9.1644e+01             189
# 21        0.0000e+00              0.0000e+00             154
# 22        0.0000e+00              0.0000e+00             187
# 23        0.0000e+00              0.0000e+00             143
# 24        0.0000e+00              0.0000e+00             125
# 25        0.0000e+00              0.0000e+00             105
# 26        0.0000e+00              0.0000e+00             120
# 27        0.0000e+00              0.0000e+00             126
# 28        0.0000e+00              0.0000e+00             119
# 29        0.0000e+00              0.0000e+00             119
# 30        0.0000e+00              0.0000e+00             135
# 31        0.0000e+00              0.0000e+00               9
# 32        0.0000e+00              0.0000e+00               9
# 33        0.0000e+00              0.0000e+00             132
# 34        0.0000e+00              0.0000e+00             231
# 35        0.0000e+00              0.0000e+00             209
# 36        0.0000e+00              0.0000e+00             105
# 37        0.0000e+00              0.0000e+00             120
# 38        0.0000e+00              0.0000e+00             145
# 39        0.0000e+00              0.0000e+00             147
# 40        0.0000e+00              0.0000e+00               7
# 41        0.0000e+00              0.0000e+00             147
# 42        0.0000e+00              0.0000e+00             126
# 43        0.0000e+00              0.0000e+00              27
# 44        0.0000e+00              0.0000e+00             108
# 45        0.0000e+00              0.0000e+00             231
# 46        0.0000e+00              0.0000e+00             154
# 47        0.0000e+00              0.0000e+00             209

# %%
# all coils overlaid vs weight_fb (4 panels)
df['flux_shared'] = df['best_flux_err'] / df['norm_fixed']
df['fb_shared']   = df['best_fb_cost']  / df['norm_fb']

panels = [
    [('best_flux_err',    'flux err | raw',                         False),
     ('best_fb_cost',     'fb cost | raw',                          True)],
    [('fb_shared',        'fb cost | norm: max(init_l, init_b)',    True),
     ('best_cost_shared', 'total cost | norm: max(init_l, init_b)', True)],
]

sweeps = sorted(df['sweep'].unique())
coils = sorted(df['num_coils'].unique())
coil_colors = dict(zip(coils, plt.cm.viridis(np.linspace(0, 0.85, len(coils)))))
sweep_styles = {sweeps[0]: '-', sweeps[1]: '--'} if len(sweeps) >= 2 else {sweeps[0]: '-'}
sweep_markers = {sweeps[0]: 'o', sweeps[1]: 's'} if len(sweeps) >= 2 else {sweeps[0]: 'o'}
sweep_short = {s: ('Bayesian' if 'b_temp' in s else 'L-BFGS' if 'l_temp' in s else s) for s in sweeps}
style_word = {'-': 'solid', '--': 'dashed'}

fig, axes = plt.subplots(2, 2, figsize=(13, 9), squeeze=False)
for row, cols in enumerate(panels):
    for col, (metric, ylabel, log_y) in enumerate(cols):
        ax = axes[row][col]
        for sweep in sweeps:
            for nc in coils:
                sub = df[(df['sweep'] == sweep) & (df['num_coils'] == nc)].sort_values('weight_fb')
                if sub.empty:
                    continue
                ax.plot(sub['weight_fb'], sub[metric],
                        color=coil_colors[nc], ls=sweep_styles[sweep],
                        marker=sweep_markers[sweep], lw=1.4, ms=5,
                        label=f'{sweep_short[sweep]} ({style_word[sweep_styles[sweep]]}) c={nc}')
        ax.set_xscale('log')
        if log_y:
            ax.set_yscale('log')
        ax.set_xlabel('weight_fb')
        ax.set_ylabel(ylabel)
        ax.set_title(ylabel, fontsize=9)
        ax.grid(True, alpha=0.3)
axes[0][0].legend(fontsize=6, loc='best', ncol=2)
plt.tight_layout()
plt.show()

# %%
# all weight_fb overlaid vs num_coils (4 panels)
panels = [
    [('best_flux_err',    'flux err | raw',                         False),
     ('best_fb_cost',     'fb cost | raw',                          True)],
    [('fb_shared',        'fb cost | norm: max(init_l, init_b)',    True),
     ('best_cost_shared', 'total cost | norm: max(init_l, init_b)', True)],
]

weights = sorted(df['weight_fb'].unique())
weight_colors = dict(zip(weights, plt.cm.viridis(np.linspace(0, 0.85, len(weights)))))

fig, axes = plt.subplots(2, 2, figsize=(13, 9), squeeze=False)
for row, cols in enumerate(panels):
    for col, (metric, ylabel, log_y) in enumerate(cols):
        ax = axes[row][col]
        for sweep in sweeps:
            for w in weights:
                sub = df[(df['sweep'] == sweep) & (df['weight_fb'] == w)].sort_values('num_coils')
                if sub.empty:
                    continue
                ax.plot(sub['num_coils'], sub[metric],
                        color=weight_colors[w], ls=sweep_styles[sweep],
                        marker=sweep_markers[sweep], lw=1.4, ms=5,
                        label=f'{sweep_short[sweep]} ({style_word[sweep_styles[sweep]]}) w={w:.0e}')
        ax.set_xticks(coils)
        if log_y:
            ax.set_yscale('log')
        ax.set_xlabel('num_coils')
        ax.set_ylabel(ylabel)
        ax.set_title(ylabel, fontsize=9)
        ax.grid(True, alpha=0.3)
axes[0][0].legend(fontsize=6, loc='best', ncol=2)
plt.tight_layout()
plt.show()
