# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
K_REFINED = 0 # None = all refinements; set e.g. 1 to truncate Bayesian after k-th refinement

# %%
LBFGS_SWEEP = 'convergence_w5_lbfgs'
BAYESIAN_SWEEP = 'convergence_w5_bayesian'

# %%
BASE = '../examples/comparisons/target=free_diiid_3_coil_06_10'

# %%
def load_run(run_dir):
    for fname in ('results.json', 'checkpoint.json'):
        path = os.path.join(run_dir, fname)
        if not os.path.exists(path):
            continue
        with open(path) as f:
            raw = json.load(f)
        methods = raw.get('methods', {})
        if not methods:
            return None
        method_name, inner = next(iter(methods.items()))
        d = dict(inner)
        d['method'] = method_name
        d['optimization_settings'] = raw.get('optimization_settings', {})
        d['source'] = fname
        d['elapsed'] = inner.get('time', float('nan'))
        return d
    return None

# %%
def load_run(run_dir):
    for fname in ('results.json', 'checkpoint.json'):
        path = os.path.join(run_dir, fname)
        if not os.path.exists(path):
            continue
        with open(path) as f:
            raw = json.load(f)
        methods = raw.get('methods', {})
        if methods:
            method_name, inner = next(iter(methods.items()))
            d = dict(inner)
            d['method'] = method_name
            d['optimization_settings'] = raw.get('optimization_settings', {})
            d['elapsed'] = inner.get('time', float('nan'))
        elif 'method' in raw:
            d = dict(raw)
            d['elapsed'] = raw.get('elapsed', float('nan'))
        else:
            continue
        d['source'] = fname
        return d
    return None

# %%
def discover_runs(base):
    runs = []
    for sweep in [LBFGS_SWEEP, BAYESIAN_SWEEP]:
        sweep_dir = os.path.join(base, sweep)
        if not os.path.isdir(sweep_dir):
            print(f"not found: {sweep_dir}")
            continue
        for config in sorted(os.listdir(sweep_dir)):
            config_dir = os.path.join(sweep_dir, config)
            if not os.path.isdir(config_dir):
                continue
            for run in sorted(os.listdir(config_dir)):
                run_dir = os.path.join(config_dir, run)
                if not os.path.isdir(run_dir):
                    continue
                d = load_run(run_dir)
                if d is None:
                    continue
                s = d.get('optimization_settings', {})
                runs.append({
                    'sweep': sweep,
                    'config': config,
                    'run': run,
                    'run_dir': run_dir,
                    'source': d['source'],
                    'method': d.get('method', '?'),
                    'weight_fb': s.get('weight_fb', float('nan')),
                    'alpha': s.get('alpha', float('nan')),
                    'num_coils': s.get('num_coils', '?'),
                    'n_evals': d.get('n_evals', float('nan')),
                    'best_cost': d.get('best_cost', float('nan')),
                    'best_flux_err': d.get('best_flux_err', float('nan')),
                    'best_fb_cost': d.get('best_fb_cost', float('nan')),
                    'fb_failures': d.get('fb_failures', float('nan')),
                    'elapsed': d.get('elapsed', d.get('time', float('nan'))),
                    'stopping': d.get('stopping', '?'),
                    'data': d,
                })
    return runs

runs = discover_runs(BASE)
print(f"{len(runs)} runs found")
for r in runs:
    print(f"  {r['sweep']}/{r['config']}/{r['run']}  method={r['method']}  weight_fb={r['weight_fb']:.0e}  best={r['best_cost']:.4e}  evals={r['n_evals']}  stop={r['stopping']}")
# Out:
# 32 runs found
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-01,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=2.3676e-02  evals=1960  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-01,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=1.8154e-09  evals=434  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-01,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=1.6936e-02  evals=1872  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-01,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-01  best=6.8472e-03  evals=4539  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-02,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.5202e-02  evals=1425  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-02,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.2104e-09  evals=623  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-02,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.6377e-03  evals=1881  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-02,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-02  best=1.2206e-03  evals=4724  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-03,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=1.5791e-02  evals=1595  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-03,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=1.2061e-09  evals=616  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-03,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=1.4415e-03  evals=2061  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-03,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-03  best=4.2877e-03  evals=5465  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-04,lambda:1e-06,coils:2/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=1.4326e-02  evals=1480  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-04,lambda:1e-06,coils:3/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=1.2061e-09  evals=637  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-04,lambda:1e-06,coils:4/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=4.6077e-04  evals=1512  stop=converged
#   convergence_w5_lbfgs/alpha:1.0,weight:1e-04,lambda:1e-06,coils:5/run_01  method=Multi-start L-BFGS  weight_fb=1e-04  best=5.8566e-03  evals=5894  stop=converged
#   convergence_w5_bayesian/alpha:1.0,weight:1e-01,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-01  best=8.1640e-03  evals=1198  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-01,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-01  best=3.2938e-03  evals=2109  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-01,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-01  best=3.3794e-02  evals=1812  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-01,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-01  best=3.8525e-03  evals=2110  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-02,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-02  best=1.0606e-02  evals=1232  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-02,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-02  best=1.9624e-03  evals=1232  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-02,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-02  best=1.7218e-03  evals=1353  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-02,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-02  best=6.2625e-04  evals=1894  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-03,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-03  best=1.1182e-02  evals=1036  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-03,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-03  best=7.9638e-04  evals=1263  stop=in_progress
#   convergence_w5_bayesian/alpha:1.0,weight:1e-03,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-03  best=5.0680e-03  evals=993  stop=in_progress
#   convergence_w5_bayesian/alpha:1.0,weight:1e-03,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-03  best=3.0294e-04  evals=2265  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-04,lambda:1e-06,coils:2/run_01  method=Bayesian  weight_fb=1e-04  best=1.0774e-02  evals=812  stop=all refinements completed
#   convergence_w5_bayesian/alpha:1.0,weight:1e-04,lambda:1e-06,coils:3/run_01  method=Bayesian  weight_fb=1e-04  best=1.0807e-03  evals=1584  stop=in_progress
#   convergence_w5_bayesian/alpha:1.0,weight:1e-04,lambda:1e-06,coils:4/run_01  method=Bayesian  weight_fb=1e-04  best=4.8004e-03  evals=1618  stop=in_progress
#   convergence_w5_bayesian/alpha:1.0,weight:1e-04,lambda:1e-06,coils:5/run_01  method=Bayesian  weight_fb=1e-04  best=9.9920e-04  evals=1099  stop=all refinements completed

# %%
rows = []
for r in runs:
    d = r['data']
    if 'cost_history' not in d:
        continue
    alpha = d.get('optimization_settings', {}).get('alpha', 0.75)
    total = np.array(d['cost_history'], dtype=float)
    flux_h = np.array([x if x is not None else np.nan for x in d.get('flux_err_history', [])], dtype=float)
    fb_h = np.array([x if x is not None else np.nan for x in d.get('fb_cost_history', [])], dtype=float)

    truncated = False
    if r['method'] == 'Bayesian' and K_REFINED is not None:
        n_bay = d.get('n_bayesian_evals', len(total))
        ref_evals = d.get('refinement_evals', [])
        trunc = n_bay + sum(ref_evals[:min(K_REFINED, len(ref_evals))])
        if trunc > 0:
            total = total[:trunc]
            flux_h = flux_h[:trunc]
            fb_h = fb_h[:trunc]
            truncated = True
        t_bay = d.get('time_bayesian_phase', float('nan'))
        ref_times = d.get('refinement_times', [])
        elapsed_h = (t_bay + sum(ref_times[:min(K_REFINED, len(ref_times))])) / 3600
    else:
        elapsed_h = r['elapsed'] / 3600

    if len(total) == 0:
        continue

    if truncated:
        idx = int(np.nanargmin(total))
        best_flux = float(flux_h[idx]) if idx < len(flux_h) and np.isfinite(flux_h[idx]) else float(np.nanmin(flux_h))
        best_fb = float(fb_h[idx]) if idx < len(fb_h) and np.isfinite(fb_h[idx]) else float(np.nanmin(fb_h))
    else:
        best_flux = float(d.get('best_flux_err', float('nan')))
        best_fb = float(d.get('best_fb_cost', float('nan')))

    rows.append({
        'sweep': r['sweep'],
        'method': r['method'],
        'weight_fb': r['weight_fb'],
        'num_coils': r['num_coils'],
        'alpha': alpha,
        'best_cost_stored': float(np.nanmin(total)),
        'best_flux_err': best_flux,
        'best_fb_cost': best_fb,
        'init_fixed': float(d.get('initial_fixed_cost', float('nan'))),
        'init_fb': float(d.get('initial_fb_cost', float('nan'))),
        'fb_failures': r['fb_failures'],
        'n_evals': len(total),
        'elapsed_h': elapsed_h,
        'stopping': r['stopping'],
    })

df = pd.DataFrame(rows)

# per weight_fb pair: norm = max(init_lbfgs, init_bayesian)
norm_df = df.groupby('weight_fb')[['init_fixed', 'init_fb']].max()
norm_df.columns = ['norm_fixed', 'norm_fb']
df = df.join(norm_df, on='weight_fb')

df['best_cost_shared'] = (
    (1 - df['alpha']) * df['best_flux_err'] / df['norm_fixed'] +
    df['alpha'] * df['best_fb_cost'] / df['norm_fb']
)

df = df.sort_values(['weight_fb', 'method'])
pd.set_option('display.float_format', '{:.4e}'.format)
display(df)
# Out:
#                       sweep              method  weight_fb  num_coils  \
# 28  convergence_w5_bayesian            Bayesian 1.0000e-04          2
# 29  convergence_w5_bayesian            Bayesian 1.0000e-04          3
# 30  convergence_w5_bayesian            Bayesian 1.0000e-04          4
# 31  convergence_w5_bayesian            Bayesian 1.0000e-04          5
# 12     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          2
# 13     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          3
# 14     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          4
# 15     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          5
# 24  convergence_w5_bayesian            Bayesian 1.0000e-03          2
# 25  convergence_w5_bayesian            Bayesian 1.0000e-03          3
# 26  convergence_w5_bayesian            Bayesian 1.0000e-03          4
# 27  convergence_w5_bayesian            Bayesian 1.0000e-03          5
# 8      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          2
# 9      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          3
# 10     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          4
# 11     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          5
# 20  convergence_w5_bayesian            Bayesian 1.0000e-02          2
# 21  convergence_w5_bayesian            Bayesian 1.0000e-02          3
# 22  convergence_w5_bayesian            Bayesian 1.0000e-02          4
# 23  convergence_w5_bayesian            Bayesian 1.0000e-02          5
# 4      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          2
# 5      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          3
# 6      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          4
# 7      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          5
# 16  convergence_w5_bayesian            Bayesian 1.0000e-01          2
# 17  convergence_w5_bayesian            Bayesian 1.0000e-01          3
# 18  convergence_w5_bayesian            Bayesian 1.0000e-01          4
# 19  convergence_w5_bayesian            Bayesian 1.0000e-01          5
# 0      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          2
# 1      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          3
# 2      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          4
# 3      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          5
#
#         alpha  best_cost_stored  best_flux_err  best_fb_cost  init_fixed  \
# 28 1.0000e+00        1.0774e-02     2.4442e-03    5.6457e-04  2.1965e-01
# 29 1.0000e+00        1.0807e-03     3.5083e-03    5.4302e-05  8.8499e-02
# 30 1.0000e+00        4.8004e-03     3.7265e-03    4.4528e-05  1.8421e-02
# 31 1.0000e+00        9.9920e-04     1.5405e-03    9.3823e-06  3.8547e-02
# 12 1.0000e+00        1.4326e-02     2.6050e-03    5.4695e-04  2.6537e-01
# 13 1.0000e+00        1.2061e-09     7.6931e-03    1.2061e-03  2.6903e-01
# 14 1.0000e+00        4.6077e-04     3.3803e-03    1.9246e-05  2.3110e-01
# 15 1.0000e+00        5.8566e-03     1.3100e-03    1.1157e-04  1.7769e-01
# 24 1.0000e+00        1.1182e-02     5.5479e-03    5.8589e-04  2.1965e-01
# 25 1.0000e+00        7.9638e-04     6.8418e-03    4.0114e-05  8.8499e-02
# 26 1.0000e+00        5.0680e-03     1.1416e-03    4.6750e-05  1.8421e-02
# 27 1.0000e+00        3.0294e-04     7.9422e-04    2.8277e-06  3.8547e-02
# 8  1.0000e+00        1.5791e-02     2.8583e-03    6.0285e-04  2.6537e-01
# 9  1.0000e+00        1.2061e-09     7.6931e-03    1.2061e-03  2.6903e-01
# 10 1.0000e+00        1.4415e-03     3.4092e-03    6.2262e-05  2.3110e-01
# 11 1.0000e+00        4.2877e-03     1.0353e-03    8.8160e-05  1.7769e-01
# 20 1.0000e+00        1.0606e-02     2.6088e-03    5.4871e-04  2.1965e-01
# 21 1.0000e+00        1.9624e-03     4.5375e-03    1.2381e-04  8.8499e-02
# 22 1.0000e+00        1.7218e-03     2.8716e-03    1.4946e-05  1.8421e-02
# 23 1.0000e+00        6.2625e-04     1.3716e-03    3.6263e-06  3.8547e-02
# 4  1.0000e+00        1.5202e-02     2.7750e-03    5.7772e-04  2.6537e-01
# 5  1.0000e+00        1.2104e-09     7.6931e-03    1.2104e-03  2.6903e-01
# 6  1.0000e+00        1.6377e-03     3.2407e-03    9.4748e-05  2.3110e-01
# 7  1.0000e+00        1.2206e-03     1.9493e-03    4.9362e-05  1.7769e-01
# 16 1.0000e+00        8.1640e-03     3.7087e-03    4.8347e-04  2.1965e-01
# 17 1.0000e+00        3.2938e-03     9.3753e-04    9.2426e-05  8.8499e-02
# 18 1.0000e+00        3.3794e-02     1.3278e-03    9.2643e-05  1.8421e-02
# 19 1.0000e+00        3.8525e-03     5.9761e-04    5.4306e-05  3.8547e-02
# 0  1.0000e+00        2.3676e-02     2.7664e-03    9.1280e-04  2.6537e-01
# 1  1.0000e+00        1.8154e-09     7.6931e-03    1.8154e-03  2.6903e-01
# 2  1.0000e+00        1.6936e-02     1.2694e-03    5.5748e-04  2.3110e-01
# 3  1.0000e+00        6.8472e-03     1.3478e-03    1.8844e-04  1.7769e-01
#
#       init_fb  fb_failures  n_evals  elapsed_h                   stopping  \
# 28 1.0000e+06          129      557 8.2748e+00  all refinements completed
# 29 5.0245e-02           58     1584        NaN                in_progress
# 30 9.2760e-03          106     1618        NaN                in_progress
# 31 9.3898e-03          347      626 1.1403e+01  all refinements completed
# 12 3.8180e-02           34     1480 1.8636e+01                  converged
# 13 1.0000e+06           91      637 8.4336e+00                  converged
# 14 4.1768e-02          153     1512 1.9462e+01                  converged
# 15 1.9051e-02          418     5894 7.5198e+01                  converged
# 24 1.0000e+06           80      551 8.1555e+00  all refinements completed
# 25 5.0370e-02           56     1263        NaN                in_progress
# 26 9.2245e-03           73      993        NaN                in_progress
# 27 9.3342e-03          142     1055 2.9331e+01  all refinements completed
# 8  3.8178e-02           30     1595 2.0330e+01                  converged
# 9  1.0000e+06           70      616 7.8603e+00                  converged
# 10 4.3192e-02          153     2061 2.6892e+01                  converged
# 11 2.0561e-02          617     5465 7.0064e+01                  converged
# 20 1.0000e+06          220      697 1.0753e+01  all refinements completed
# 21 1.0000e+06          139      630 8.6030e+00  all refinements completed
# 22 8.6804e-03           63      633 9.7450e+00  all refinements completed
# 23 5.7905e-03          149      684 1.1320e+01  all refinements completed
# 4  3.8003e-02          110     1425 1.7813e+01                  converged
# 5  1.0000e+06           70      623 7.9817e+00                  converged
# 6  5.7854e-02           99     1881 2.4634e+01                  converged
# 7  4.0441e-02          407     4724 6.0073e+01                  converged
# 16 5.9220e-02           30      863 1.5822e+01  all refinements completed
# 17 2.8061e-02           52     1311 3.5315e+01  all refinements completed
# 18 2.7414e-03           87      642 1.0004e+01  all refinements completed
# 19 1.4096e-02           98      812 1.5915e+01  all refinements completed
# 0  3.8553e-02           90     1960 2.4514e+01                  converged
# 1  1.0000e+06           70      434 5.6085e+00                  converged
# 2  3.2917e-02          189     1872 2.4088e+01                  converged
# 3  2.7520e-02          451     4539 5.6390e+01                  converged
#
#     norm_fixed    norm_fb  best_cost_shared
# 28  2.6903e-01 1.0000e+06        5.6457e-10
# 29  2.6903e-01 1.0000e+06        5.4302e-11
# 30  2.6903e-01 1.0000e+06        4.4528e-11
# 31  2.6903e-01 1.0000e+06        9.3823e-12
# 12  2.6903e-01 1.0000e+06        5.4695e-10
# 13  2.6903e-01 1.0000e+06        1.2061e-09
# 14  2.6903e-01 1.0000e+06        1.9246e-11
# 15  2.6903e-01 1.0000e+06        1.1157e-10
# 24  2.6903e-01 1.0000e+06        5.8589e-10
# 25  2.6903e-01 1.0000e+06        4.0114e-11
# 26  2.6903e-01 1.0000e+06        4.6750e-11
# 27  2.6903e-01 1.0000e+06        2.8277e-12
# 8   2.6903e-01 1.0000e+06        6.0285e-10
# 9   2.6903e-01 1.0000e+06        1.2061e-09
# 10  2.6903e-01 1.0000e+06        6.2262e-11
# 11  2.6903e-01 1.0000e+06        8.8160e-11
# 20  2.6903e-01 1.0000e+06        5.4871e-10
# 21  2.6903e-01 1.0000e+06        1.2381e-10
# 22  2.6903e-01 1.0000e+06        1.4946e-11
# 23  2.6903e-01 1.0000e+06        3.6263e-12
# 4   2.6903e-01 1.0000e+06        5.7772e-10
# 5   2.6903e-01 1.0000e+06        1.2104e-09
# 6   2.6903e-01 1.0000e+06        9.4748e-11
# 7   2.6903e-01 1.0000e+06        4.9362e-11
# 16  2.6903e-01 1.0000e+06        4.8347e-10
# 17  2.6903e-01 1.0000e+06        9.2426e-11
# 18  2.6903e-01 1.0000e+06        9.2643e-11
# 19  2.6903e-01 1.0000e+06        5.4306e-11
# 0   2.6903e-01 1.0000e+06        9.1280e-10
# 1   2.6903e-01 1.0000e+06        1.8154e-09
# 2   2.6903e-01 1.0000e+06        5.5748e-10
# 3   2.6903e-01 1.0000e+06        1.8844e-10

# %%
# fix norm: per (weight_fb, num_coils), drop 1e6 init_fb sentinel
df = df.drop(columns=['norm_fixed', 'norm_fb', 'best_cost_shared'])
clean = df.assign(
    init_fixed=df['init_fixed'].where(df['init_fixed'] < 1e5),
    init_fb=df['init_fb'].where(df['init_fb'] < 1e5),
)
norm_df = clean.groupby(['weight_fb', 'num_coils'])[['init_fixed', 'init_fb']].max()
norm_df.columns = ['norm_fixed', 'norm_fb']
df = df.join(norm_df, on=['weight_fb', 'num_coils'])
df['best_cost_shared'] = (
    (1 - df['alpha']) * df['best_flux_err'] / df['norm_fixed'] +
    df['alpha'] * df['best_fb_cost'] / df['norm_fb']
)
df[['sweep', 'method', 'weight_fb', 'num_coils', 'init_fixed', 'init_fb', 'norm_fixed', 'norm_fb', 'best_cost_shared']]
# Out:
#                       sweep              method  weight_fb  num_coils  \
# 28  convergence_w5_bayesian            Bayesian 1.0000e-04          2
# 29  convergence_w5_bayesian            Bayesian 1.0000e-04          3
# 30  convergence_w5_bayesian            Bayesian 1.0000e-04          4
# 31  convergence_w5_bayesian            Bayesian 1.0000e-04          5
# 12     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          2
# 13     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          3
# 14     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          4
# 15     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-04          5
# 24  convergence_w5_bayesian            Bayesian 1.0000e-03          2
# 25  convergence_w5_bayesian            Bayesian 1.0000e-03          3
# 26  convergence_w5_bayesian            Bayesian 1.0000e-03          4
# 27  convergence_w5_bayesian            Bayesian 1.0000e-03          5
# 8      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          2
# 9      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          3
# 10     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          4
# 11     convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-03          5
# 20  convergence_w5_bayesian            Bayesian 1.0000e-02          2
# 21  convergence_w5_bayesian            Bayesian 1.0000e-02          3
# 22  convergence_w5_bayesian            Bayesian 1.0000e-02          4
# 23  convergence_w5_bayesian            Bayesian 1.0000e-02          5
# 4      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          2
# 5      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          3
# 6      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          4
# 7      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-02          5
# 16  convergence_w5_bayesian            Bayesian 1.0000e-01          2
# 17  convergence_w5_bayesian            Bayesian 1.0000e-01          3
# 18  convergence_w5_bayesian            Bayesian 1.0000e-01          4
# 19  convergence_w5_bayesian            Bayesian 1.0000e-01          5
# 0      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          2
# 1      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          3
# 2      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          4
# 3      convergence_w5_lbfgs  Multi-start L-BFGS 1.0000e-01          5
#
#     init_fixed    init_fb  norm_fixed    norm_fb  best_cost_shared
# 28  2.1965e-01 1.0000e+06  2.6537e-01 3.8180e-02        1.4787e-02
# 29  8.8499e-02 5.0245e-02  2.6903e-01 5.0245e-02        1.0807e-03
# 30  1.8421e-02 9.2760e-03  2.3110e-01 4.1768e-02        1.0661e-03
# 31  3.8547e-02 9.3898e-03  1.7769e-01 1.9051e-02        4.9250e-04
# 12  2.6537e-01 3.8180e-02  2.6537e-01 3.8180e-02        1.4326e-02
# 13  2.6903e-01 1.0000e+06  2.6903e-01 5.0245e-02        2.4004e-02
# 14  2.3110e-01 4.1768e-02  2.3110e-01 4.1768e-02        4.6077e-04
# 15  1.7769e-01 1.9051e-02  1.7769e-01 1.9051e-02        5.8566e-03
# 24  2.1965e-01 1.0000e+06  2.6537e-01 3.8178e-02        1.5346e-02
# 25  8.8499e-02 5.0370e-02  2.6903e-01 5.0370e-02        7.9638e-04
# 26  1.8421e-02 9.2245e-03  2.3110e-01 4.3192e-02        1.0824e-03
# 27  3.8547e-02 9.3342e-03  1.7769e-01 2.0561e-02        1.3753e-04
# 8   2.6537e-01 3.8178e-02  2.6537e-01 3.8178e-02        1.5791e-02
# 9   2.6903e-01 1.0000e+06  2.6903e-01 5.0370e-02        2.3945e-02
# 10  2.3110e-01 4.3192e-02  2.3110e-01 4.3192e-02        1.4415e-03
# 11  1.7769e-01 2.0561e-02  1.7769e-01 2.0561e-02        4.2877e-03
# 20  2.1965e-01 1.0000e+06  2.6537e-01 3.8003e-02        1.4439e-02
# 21  8.8499e-02 1.0000e+06  2.6903e-01        NaN               NaN
# 22  1.8421e-02 8.6804e-03  2.3110e-01 5.7854e-02        2.5834e-04
# 23  3.8547e-02 5.7905e-03  1.7769e-01 4.0441e-02        8.9669e-05
# 4   2.6537e-01 3.8003e-02  2.6537e-01 3.8003e-02        1.5202e-02
# 5   2.6903e-01 1.0000e+06  2.6903e-01        NaN               NaN
# 6   2.3110e-01 5.7854e-02  2.3110e-01 5.7854e-02        1.6377e-03
# 7   1.7769e-01 4.0441e-02  1.7769e-01 4.0441e-02        1.2206e-03
# 16  2.1965e-01 5.9220e-02  2.6537e-01 5.9220e-02        8.1640e-03
# 17  8.8499e-02 2.8061e-02  2.6903e-01 2.8061e-02        3.2938e-03
# 18  1.8421e-02 2.7414e-03  2.3110e-01 3.2917e-02        2.8145e-03
# 19  3.8547e-02 1.4096e-02  1.7769e-01 2.7520e-02        1.9733e-03
# 0   2.6537e-01 3.8553e-02  2.6537e-01 5.9220e-02        1.5414e-02
# 1   2.6903e-01 1.0000e+06  2.6903e-01 2.8061e-02        6.4697e-02
# 2   2.3110e-01 3.2917e-02  2.3110e-01 3.2917e-02        1.6936e-02
# 3   1.7769e-01 2.7520e-02  1.7769e-01 2.7520e-02        6.8472e-03

# %%
# run counts split by method
for method in sorted(df['method'].unique()):
    sub = df[df['method'] == method]
    piv = sub.groupby(['num_coils', 'weight_fb']).size().unstack(fill_value=0).astype(int)
    piv = piv.reindex(sorted(piv.columns), axis=1)
    piv.columns = [f'{c:.0e}' for c in piv.columns]
    print(method)
    display(piv)
# Out:
# Bayesian
#            1e-04  1e-03  1e-02  1e-01
# num_coils
# 2              1      1      1      1
# 3              1      1      1      1
# 4              1      1      1      1
# 5              1      1      1      1
# Multi-start L-BFGS
#            1e-04  1e-03  1e-02  1e-01
# num_coils
# 2              1      1      1      1
# 3              1      1      1      1
# 4              1      1      1      1
# 5              1      1      1      1

# %%
# raw fb cost split by method (rows num_coils, cols weight_fb)
for method in sorted(df['method'].unique()):
    sub = df[df['method'] == method]
    piv = sub.groupby(['num_coils', 'weight_fb'])['best_fb_cost'].min().unstack()
    piv = piv.reindex(sorted(piv.columns), axis=1)
    piv.columns = [f'{c:.0e}' for c in piv.columns]
    print(method)
    display(piv)

with open(f'{BASE}/fb_candidate_cost_results.json') as _f:
    _true_raw = json.load(_f)
WEIGHTS_STR = ['1e-04', '1e-03', '1e-02', '1e-01']
true_piv = pd.DataFrame([{w: _true_raw.get(w, float('nan')) for w in WEIGHTS_STR}], index=['True DIII-D'])
print('True DIII-D (3 coils)')
display(true_piv.style.format('{:.4e}'))
# Out:
# Bayesian
#                1e-04      1e-03      1e-02      1e-01
# num_coils
# 2         5.6457e-04 5.8589e-04 5.4871e-04 4.8347e-04
# 3         5.4302e-05 4.0114e-05 1.2381e-04 9.2426e-05
# 4         4.4528e-05 4.6750e-05 1.4946e-05 9.2643e-05
# 5         9.3823e-06 2.8277e-06 3.6263e-06 5.4306e-05
# Multi-start L-BFGS
#                1e-04      1e-03      1e-02      1e-01
# num_coils
# 2         5.4695e-04 6.0285e-04 5.7772e-04 9.1280e-04
# 3         1.2061e-03 1.2061e-03 1.2104e-03 1.8154e-03
# 4         1.9246e-05 6.2262e-05 9.4748e-05 5.5748e-04
# 5         1.1157e-04 8.8160e-05 4.9362e-05 1.8844e-04
# True DIII-D (3 coils)
# <style type="text/css">
# </style>
# <table id="T_70fd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70fd0_level0_col0" class="col_heading level0 col0" >1e-04</th>
#       <th id="T_70fd0_level0_col1" class="col_heading level0 col1" >1e-03</th>
#       <th id="T_70fd0_level0_col2" class="col_heading level0 col2" >1e-02</th>
#       <th id="T_70fd0_level0_col3" class="col_heading level0 col3" >1e-01</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70fd0_level0_row0" class="row_heading level0 row0" >True DIII-D</th>
#       <td id="T_70fd0_row0_col0" class="data row0 col0" >7.8935e-05</td>
#       <td id="T_70fd0_row0_col1" class="data row0 col1" >7.8935e-05</td>
#       <td id="T_70fd0_row0_col2" class="data row0 col2" >7.8935e-05</td>
#       <td id="T_70fd0_row0_col3" class="data row0 col3" >7.8935e-05</td>
#     </tr>
#   </tbody>
# </table>

# %%
true_vals = {w: _true_raw.get(w, float('nan')) for w in WEIGHTS_STR}

methods = sorted(df['method'].unique())
fig, axes = plt.subplots(1, len(methods), figsize=(7 * len(methods), 5))
if len(methods) == 1:
    axes = [axes]

for ax, method in zip(axes, methods):
    ratio_rows = {}
    for nc in sorted(df['num_coils'].unique()):
        row = {}
        for w_str in WEIGHTS_STR:
            w_float = float(w_str)
            match = df[(df['method'] == method) & (df['num_coils'] == nc) & np.isclose(df['weight_fb'], w_float)]
            opt_best = float(match['best_fb_cost'].min()) if len(match) > 0 else float('nan')
            row[w_str] = opt_best / true_vals[w_str]
        ratio_rows[nc] = row
    ratio_df = pd.DataFrame(ratio_rows).T[WEIGHTS_STR]
    ratio_df.index.name = 'num_coils'
    sns.heatmap(ratio_df, annot=True, fmt='.3f', cmap='RdYlGn_r', ax=ax, center=1.0,
                cbar_kws={'label': 'optimizer fb / true fb'})
    ax.set_title(f'{method}\nfb_cost ratio vs True DIII-D — <1 optimizer better')
    ax.set_xlabel('weight_fb')
    ax.set_ylabel('num_coils')

plt.tight_layout()
plt.show()

# %%
with open('target=free_diiid_3_coil/fb_candidate_cost_results.json') as f:
    _true = json.load(f)

WEIGHTS_STR = ['1e-04', '1e-03', '1e-02', '1e-01']
true_row = [_true.get(w, float('nan')) for w in WEIGHTS_STR]
sub3 = df[df['num_coils'] == 3]

for method_label, method_key in [('Bayesian', 'Bayesian'), ('L-BFGS', 'Multi-start L-BFGS')]:
    opt_row = []
    for w_str in WEIGHTS_STR:
        w_float = float(w_str)
        match = sub3[(sub3['method'] == method_key) & np.isclose(sub3['weight_fb'], w_float)]
        opt_row.append(float(match['best_fb_cost'].min()) if len(match) > 0 else float('nan'))
    tbl = pd.DataFrame(
        [true_row, opt_row],
        index=['True DIII-D (3 coils)', method_label],
        columns=WEIGHTS_STR
    )
    print(f'True DIII-D vs {method_label} | raw fb_cost | 3 coils')
    display(tbl.style.format('{:.4e}'))
    print()
# Out:
# True DIII-D vs Bayesian | raw fb_cost | 3 coils
# <style type="text/css">
# </style>
# <table id="T_14cba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14cba_level0_col0" class="col_heading level0 col0" >1e-04</th>
#       <th id="T_14cba_level0_col1" class="col_heading level0 col1" >1e-03</th>
#       <th id="T_14cba_level0_col2" class="col_heading level0 col2" >1e-02</th>
#       <th id="T_14cba_level0_col3" class="col_heading level0 col3" >1e-01</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14cba_level0_row0" class="row_heading level0 row0" >True DIII-D (3 coils)</th>
#       <td id="T_14cba_row0_col0" class="data row0 col0" >7.8437e-12</td>
#       <td id="T_14cba_row0_col1" class="data row0 col1" >7.8437e-12</td>
#       <td id="T_14cba_row0_col2" class="data row0 col2" >7.8437e-12</td>
#       <td id="T_14cba_row0_col3" class="data row0 col3" >7.8437e-12</td>
#     </tr>
#     <tr>
#       <th id="T_14cba_level0_row1" class="row_heading level0 row1" >Bayesian</th>
#       <td id="T_14cba_row1_col0" class="data row1 col0" >5.4302e-05</td>
#       <td id="T_14cba_row1_col1" class="data row1 col1" >4.0114e-05</td>
#       <td id="T_14cba_row1_col2" class="data row1 col2" >1.2381e-04</td>
#       <td id="T_14cba_row1_col3" class="data row1 col3" >9.2426e-05</td>
#     </tr>
#   </tbody>
# </table>
# True DIII-D vs L-BFGS | raw fb_cost | 3 coils
# <style type="text/css">
# </style>
# <table id="T_81a03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81a03_level0_col0" class="col_heading level0 col0" >1e-04</th>
#       <th id="T_81a03_level0_col1" class="col_heading level0 col1" >1e-03</th>
#       <th id="T_81a03_level0_col2" class="col_heading level0 col2" >1e-02</th>
#       <th id="T_81a03_level0_col3" class="col_heading level0 col3" >1e-01</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81a03_level0_row0" class="row_heading level0 row0" >True DIII-D (3 coils)</th>
#       <td id="T_81a03_row0_col0" class="data row0 col0" >7.8437e-12</td>
#       <td id="T_81a03_row0_col1" class="data row0 col1" >7.8437e-12</td>
#       <td id="T_81a03_row0_col2" class="data row0 col2" >7.8437e-12</td>
#       <td id="T_81a03_row0_col3" class="data row0 col3" >7.8437e-12</td>
#     </tr>
#     <tr>
#       <th id="T_81a03_level0_row1" class="row_heading level0 row1" >L-BFGS</th>
#       <td id="T_81a03_row1_col0" class="data row1 col0" >1.2061e-03</td>
#       <td id="T_81a03_row1_col1" class="data row1 col1" >1.2061e-03</td>
#       <td id="T_81a03_row1_col2" class="data row1 col2" >1.2104e-03</td>
#       <td id="T_81a03_row1_col3" class="data row1 col3" >1.8154e-03</td>
#     </tr>
#   </tbody>
# </table>

# %%
# bay vs lbfgs heatmaps across (coils x weight_fb) - mirrors bay_vs_lbfgs.ipynb style
# Gap measured on free-boundary cost (best_fb_cost) only.
best = df.sort_values('best_fb_cost').groupby(['num_coils', 'weight_fb', 'method'], sort=False).first().reset_index()

bay = best[best['method'] == 'Bayesian'].set_index(['num_coils', 'weight_fb'])
lbf = best[best['method'] != 'Bayesian'].set_index(['num_coils', 'weight_fb'])

cmp = pd.DataFrame(index=bay.index.union(lbf.index))
cmp['bayes_fb'] = bay['best_fb_cost']
cmp['lbfgs_fb'] = lbf['best_fb_cost']
cmp['bayes_evals'] = bay['n_evals']
cmp['lbfgs_evals'] = lbf['n_evals']
cmp['bayes_time_h'] = bay['elapsed_h']
cmp['lbfgs_time_h'] = lbf['elapsed_h']
cmp['fb_gap_lbfgs'] = (cmp['bayes_fb'] - cmp['lbfgs_fb']) / cmp['lbfgs_fb'] * 100
cmp['eval_ratio'] = cmp['lbfgs_evals'] / cmp['bayes_evals']
cmp = cmp.reset_index()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, col, title, fmt in [
    (axes[0], 'eval_ratio', 'Eval ratio: L-BFGS / Bayesian', '.2f'),
    (axes[1], 'fb_gap_lbfgs', 'fb cost gap vs L-BFGS (%) - positive = BO worse', '.1f'),
]:
    pivot = cmp.pivot_table(index='num_coils', columns='weight_fb', values=col)
    pivot = pivot.reindex(sorted(pivot.columns), axis=1)
    pivot.columns = [f'{c:.0e}' for c in pivot.columns]
    cmap = 'YlGn' if col == 'eval_ratio' else 'RdYlGn_r'
    center = None if col == 'eval_ratio' else 0
    sns.heatmap(pivot, annot=True, fmt=fmt, cmap=cmap, ax=ax, center=center)
    ax.set_title(title)
    ax.set_xlabel('weight_fb')
    ax.set_ylabel('coils')
plt.tight_layout()
plt.show()

# timing heatmaps
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
for ax, mcol, title in [
    (axes[0], 'bayes_time_h', 'Bayesian wall time (h)'),
    (axes[1], 'lbfgs_time_h', 'L-BFGS wall time (h)'),
]:
    pivot = cmp.pivot_table(index='num_coils', columns='weight_fb', values=mcol)
    pivot = pivot.reindex(sorted(pivot.columns), axis=1)
    pivot.columns = [f'{c:.0e}' for c in pivot.columns]
    sns.heatmap(pivot, annot=True, fmt='.2f', cmap='YlOrRd', ax=ax)
    ax.set_title(title)
    ax.set_xlabel('weight_fb')
    ax.set_ylabel('coils')
plt.tight_layout()
plt.show()

# %%
# bayesian refinement improvement: % cost reduction from end of GP phase to end of each refinement
ref_rows = []
for r in runs:
    if r['method'] != 'Bayesian':
        continue
    d = r['data']
    total = np.array(d['cost_history'], dtype=float)
    n_bay = d.get('n_bayesian_evals', 0)
    ref_evals = d.get('refinement_evals', []) or []
    if n_bay == 0 or len(total) <= n_bay:
        continue
    best_gp = float(np.nanmin(total[:n_bay]))
    cum = n_bay
    cum_best = best_gp
    for i, re in enumerate(ref_evals):
        prev_best = cum_best
        cum += re
        cum_best = float(np.nanmin(total[:cum]))
        step_improve = (prev_best - cum_best) / prev_best * 100 if prev_best > 0 else float('nan')
        cumulative_improve = (best_gp - cum_best) / best_gp * 100 if best_gp > 0 else float('nan')
        ref_rows.append({
            'num_coils': r['num_coils'],
            'weight_fb': r['weight_fb'],
            'refinement': i + 1,
            'best_gp': best_gp,
            'best_after_ref': cum_best,
            'step_improve_pct': step_improve,
            'cumulative_improve_pct': cumulative_improve,
            'n_evals_in_ref': re,
        })

ref_df = pd.DataFrame(ref_rows)
print('per-refinement breakdown:')
display(ref_df)

# total improvement per (coils, weight_fb): last refinement
total_imp = ref_df.sort_values('refinement').groupby(['num_coils', 'weight_fb']).last().reset_index()

fig, axes = plt.subplots(1, 1, figsize=(7, 5))
piv_total = total_imp.pivot_table(index='num_coils', columns='weight_fb', values='cumulative_improve_pct')
piv_total = piv_total.reindex(sorted(piv_total.columns), axis=1)
piv_total.columns = [f'{c:.0e}' for c in piv_total.columns]
sns.heatmap(piv_total, annot=True, fmt='.1f', cmap='YlGn', ax=axes)
axes.set_title('Bayesian: total % cost improvement from refinements (GP_end -> final)')
axes.set_xlabel('weight_fb')
axes.set_ylabel('coils')

plt.tight_layout()
plt.show()
# Out:
# per-refinement breakdown:
#     num_coils  weight_fb  refinement    best_gp  best_after_ref  \
# 0           2 1.0000e-01           1 8.1640e-03      8.1640e-03
# 1           2 1.0000e-01           2 8.1640e-03      8.1640e-03
# 2           2 1.0000e-01           3 8.1640e-03      8.1640e-03
# 3           3 1.0000e-01           1 3.2938e-03      3.2938e-03
# 4           3 1.0000e-01           2 3.2938e-03      3.2938e-03
# 5           3 1.0000e-01           3 3.2938e-03      3.2938e-03
# 6           4 1.0000e-01           1 3.3794e-02      3.3794e-02
# 7           4 1.0000e-01           2 3.3794e-02      3.3794e-02
# 8           4 1.0000e-01           3 3.3794e-02      3.3794e-02
# 9           5 1.0000e-01           1 3.8525e-03      3.8525e-03
# 10          5 1.0000e-01           2 3.8525e-03      3.8525e-03
# 11          5 1.0000e-01           3 3.8525e-03      3.8525e-03
# 12          2 1.0000e-02           1 1.0606e-02      1.0606e-02
# 13          2 1.0000e-02           2 1.0606e-02      1.0606e-02
# 14          2 1.0000e-02           3 1.0606e-02      1.0606e-02
# 15          3 1.0000e-02           1 1.9624e-03      1.9624e-03
# 16          3 1.0000e-02           2 1.9624e-03      1.9624e-03
# 17          3 1.0000e-02           3 1.9624e-03      1.9624e-03
# 18          4 1.0000e-02           1 1.7218e-03      1.7218e-03
# 19          4 1.0000e-02           2 1.7218e-03      1.7218e-03
# 20          4 1.0000e-02           3 1.7218e-03      1.7218e-03
# 21          5 1.0000e-02           1 6.2625e-04      6.2625e-04
# 22          5 1.0000e-02           2 6.2625e-04      6.2625e-04
# 23          5 1.0000e-02           3 6.2625e-04      6.2625e-04
# 24          2 1.0000e-03           1 1.1182e-02      1.1182e-02
# 25          2 1.0000e-03           2 1.1182e-02      1.1182e-02
# 26          2 1.0000e-03           3 1.1182e-02      1.1182e-02
# 27          5 1.0000e-03           1 3.0294e-04      3.0294e-04
# 28          5 1.0000e-03           2 3.0294e-04      3.0294e-04
# 29          5 1.0000e-03           3 3.0294e-04      3.0294e-04
# 30          2 1.0000e-04           1 1.0774e-02      1.0774e-02
# 31          2 1.0000e-04           2 1.0774e-02      1.0774e-02
# 32          2 1.0000e-04           3 1.0774e-02      1.0774e-02
# 33          5 1.0000e-04           1 9.9920e-04      9.9920e-04
# 34          5 1.0000e-04           2 9.9920e-04      9.9920e-04
# 35          5 1.0000e-04           3 9.9920e-04      9.9920e-04
#
#     step_improve_pct  cumulative_improve_pct  n_evals_in_ref
# 0         0.0000e+00              0.0000e+00             105
# 1         0.0000e+00              0.0000e+00             125
# 2         0.0000e+00              0.0000e+00             105
# 3         0.0000e+00              0.0000e+00             315
# 4         0.0000e+00              0.0000e+00             266
# 5         0.0000e+00              0.0000e+00             217
# 6         0.0000e+00              0.0000e+00             603
# 7         0.0000e+00              0.0000e+00             225
# 8         0.0000e+00              0.0000e+00             342
# 9         0.0000e+00              0.0000e+00             627
# 10        0.0000e+00              0.0000e+00             231
# 11        0.0000e+00              0.0000e+00             440
# 12        0.0000e+00              0.0000e+00             210
# 13        0.0000e+00              0.0000e+00             105
# 14        0.0000e+00              0.0000e+00             220
# 15        0.0000e+00              0.0000e+00              49
# 16        0.0000e+00              0.0000e+00             182
# 17        0.0000e+00              0.0000e+00             371
# 18        0.0000e+00              0.0000e+00             198
# 19        0.0000e+00              0.0000e+00             189
# 20        0.0000e+00              0.0000e+00             333
# 21        0.0000e+00              0.0000e+00             352
# 22        0.0000e+00              0.0000e+00             198
# 23        0.0000e+00              0.0000e+00             660
# 24        0.0000e+00              0.0000e+00             265
# 25        0.0000e+00              0.0000e+00             110
# 26        0.0000e+00              0.0000e+00             110
# 27        0.0000e+00              0.0000e+00             748
# 28        0.0000e+00              0.0000e+00             231
# 29        0.0000e+00              0.0000e+00             231
# 30        0.0000e+00              0.0000e+00              10
# 31        0.0000e+00              0.0000e+00             105
# 32        0.0000e+00              0.0000e+00             140
# 33        0.0000e+00              0.0000e+00             231
# 34        0.0000e+00              0.0000e+00             231
# 35        0.0000e+00              0.0000e+00              11

# %%
# all coils overlaid vs weight_fb (4 panels)
df['flux_shared'] = df['best_flux_err'] / df['norm_fixed']
df['fb_shared']   = df['best_fb_cost']  / df['norm_fb']

panels = [
    [('best_flux_err',    'flux err | raw',                         False),
     ('best_fb_cost',     'fb cost | raw',                          True)],
    [('fb_shared',        'fb cost | norm: max(init_l, init_b)',    True),
     ('best_cost_shared', 'total cost | norm: max(init_l, init_b)', True)],
]

sweeps = sorted(df['sweep'].unique())
coils = sorted(df['num_coils'].unique())
coil_colors = dict(zip(coils, plt.cm.viridis(np.linspace(0, 0.85, len(coils)))))
sweep_styles = {sweeps[0]: '-', sweeps[1]: '--'} if len(sweeps) >= 2 else {sweeps[0]: '-'}
sweep_markers = {sweeps[0]: 'o', sweeps[1]: 's'} if len(sweeps) >= 2 else {sweeps[0]: 'o'}
sweep_short = {s: ('Bayesian' if 'b_temp' in s else 'L-BFGS' if 'l_temp' in s else s) for s in sweeps}
style_word = {'-': 'solid', '--': 'dashed'}

fig, axes = plt.subplots(2, 2, figsize=(13, 9), squeeze=False)
for row, cols in enumerate(panels):
    for col, (metric, ylabel, log_y) in enumerate(cols):
        ax = axes[row][col]
        for sweep in sweeps:
            for nc in coils:
                sub = df[(df['sweep'] == sweep) & (df['num_coils'] == nc)].sort_values('weight_fb')
                if sub.empty:
                    continue
                ax.plot(sub['weight_fb'], sub[metric],
                        color=coil_colors[nc], ls=sweep_styles[sweep],
                        marker=sweep_markers[sweep], lw=1.4, ms=5,
                        label=f'{sweep_short[sweep]} ({style_word[sweep_styles[sweep]]}) c={nc}')
        ax.set_xscale('log')
        if log_y:
            ax.set_yscale('log')
        ax.set_xlabel('weight_fb')
        ax.set_ylabel(ylabel)
        ax.set_title(ylabel, fontsize=9)
        ax.grid(True, alpha=0.3)
axes[0][0].legend(fontsize=6, loc='best', ncol=2)
plt.tight_layout()
plt.show()

# %%
# all weight_fb overlaid vs num_coils (4 panels)
panels = [
    [('best_flux_err',    'flux err | raw',                         False),
     ('best_fb_cost',     'fb cost | raw',                          True)],
    [('fb_shared',        'fb cost | norm: max(init_l, init_b)',    True),
     ('best_cost_shared', 'total cost | norm: max(init_l, init_b)', True)],
]

weights = sorted(df['weight_fb'].unique())
weight_colors = dict(zip(weights, plt.cm.viridis(np.linspace(0, 0.85, len(weights)))))

fig, axes = plt.subplots(2, 2, figsize=(13, 9), squeeze=False)
for row, cols in enumerate(panels):
    for col, (metric, ylabel, log_y) in enumerate(cols):
        ax = axes[row][col]
        for sweep in sweeps:
            for w in weights:
                sub = df[(df['sweep'] == sweep) & (df['weight_fb'] == w)].sort_values('num_coils')
                if sub.empty:
                    continue
                ax.plot(sub['num_coils'], sub[metric],
                        color=weight_colors[w], ls=sweep_styles[sweep],
                        marker=sweep_markers[sweep], lw=1.4, ms=5,
                        label=f'{sweep_short[sweep]} ({style_word[sweep_styles[sweep]]}) w={w:.0e}')
        ax.set_xticks(coils)
        if log_y:
            ax.set_yscale('log')
        ax.set_xlabel('num_coils')
        ax.set_ylabel(ylabel)
        ax.set_title(ylabel, fontsize=9)
        ax.grid(True, alpha=0.3)
axes[0][0].legend(fontsize=6, loc='best', ncol=2)
plt.tight_layout()
plt.show()
