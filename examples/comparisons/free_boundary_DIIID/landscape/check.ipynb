# %%
import numpy as np
d = np.load('coils:3/weight:1e-02.npz.ckpt.npz')                                                      
samples, cost = d['samples'], d['cost']  

print(samples.shape)      
print(cost.shape)        

done = np.isfinite(cost)
print(done.sum())

mask = (cost<1e6)
s_done = done[mask]
print(s_done.sum())
# Out:
# (65536, 2)
# (65536,)
# 14800
# 13011
